# %% [markdown]
# ### Import packages

# %%
from bs4 import BeautifulSoup

import pandas as pd
import requests
import warnings
import re

# %% [markdown]
# ### Load html file
#
# Load the html file (downloaded manually) from https://www.senheng.com.my/all-products/tvs-audios/tv.html. To parse the html file, we will use the BeautifulSoup package.

# %%
soup = BeautifulSoup(open("../data/data.html", encoding="utf8"), "html.parser")

# %% [markdown]
# Upon manual inspection, we find that the information of different TVs are stored within a HTML ordered list object with the class name "products-lists".

# %%
product_list = soup.find_all("ol", class_="products-list")
li_elems = product_list[0].find_all("li")

# %%
li_elems
# Out:
# [<li class="item odd" data-val='["HAI-LE32K6000T","Haier 32-Inch Full HD LED TV Model LE32K6000T"]' onclick="sendGa('HAI-LE32K6000T','Haier 32-Inch Full HD LED TV Model LE32K6000T')"><div class="item-area">
#  <div class="product-image-area">
#  <a class="product-image newamastylabels" href="https://www.senheng.com.my/haier-32-inch-full-hd-led-tv.html" title="Haier 32-Inch Full HD LED TV Model LE32K6000T">
#  <img alt="Haier 32-Inch Full HD LED TV Model LE32K6000T" class="" id="product-collection-image-25677" src="./data_manual_files/hai-le32k6000t_front_6xx.jpg"/>
#  </a>
#  </div>
#  <div class="details-area">
#  <h2 class="product-name"><a href="https://www.senheng.com.my/haier-32-inch-full-hd-led-tv.html" title="Haier 32-Inch Full HD LED TV Model LE32K6000T">Haier 32-Inch Full HD LED TV Model LE32K6000T</a></h2>
#  <div class="ratings">
#  <div class="rating-box">
#  <div class="rating" style="width:0"></div>
#  </div>
#  </div>
#  <div class="short-desc">
#  <p>Energy saving and Eco-friendly with auto control LED light output<br/>Full High-Definition 1080p resolution<br/>USB Media available<br/>HDMI Media available</p> </div>
#  <div class="action-area">
#  <div class="price" id="amlabel-product-price-25677" style="display:none"></div>
#  <div class="price-box">
#  <p class="old-price">
#  <span class="price-label">Regular Price:</span>
#  <span class="price" id="old-price-25677">
#                      RM 889.00                </span>
#  </p>
#  <p class="special-price">
#  <span class="price-label">Special Price</span>
#  <span class="price" id="product-price-25677">
#                      RM 749.00                </span>
#  </p>
#  </div>
#  <div class="regular-price" style="text-align: left;">
#  <div class="myspe_price">
#  <span class="price">RM 749.00</span> </div>
#  <div class="myreg_price">
#  <span class="price-title">RRP: </span>
#  <span class="price">RM 889.00</span> </div>
#  </div>
#  <div class="myclear"><br/>
#  <div class="actions">
#  <div class="loader-container">
#  <div class="loader">
#  <i class="ajax-loader medium animate-spin"></i>
#  </div>
#  </div>
#  <a class="addtocart" href="javascript:void(0)" onclick="setLocationAjax(this,'https://www.senheng.com.my/checkout/cart/add/uenc/aHR0cHM6Ly93d3cuc2VuaGVuZy5jb20ubXkvYWxsLXByb2R1Y3RzL3R2cy1hdWRpb3MvdHYuaHRtbD9hamF4Y2F0YWxvZz10cnVlJm1vZGU9bGlzdA,,/product/25677/form_key/c8r9odHLggDMCmop/','25677')" title="Add to Cart"><i class="icon-cart"></i><span> Add to Cart</span></a>
#  <a class="addtowishlist" href="https://www.senheng.com.my/wishlist/index/add/product/25677/form_key/c8r9odHLggDMCmop/" title="Add to Wishlist"><i class="icon-wishlist"></i></a>
#  <div class="clearer"></div>
#  </div>
#  </div>
#  </div>
#  <div class="clearer"></div>
#  </div></div></li>,
#  <li class="item even" data-val='["HAI-LE50U6600U","Haier 50-inch 4K Ultra HD Smart LED TV LE50U6600U"]' onclick="sendGa('HAI-LE50U6600U','Haier 50-inch 4K Ultra HD Smart LED TV LE50U6600U')"><div class="item-area">
#  <div class="product-image-area">
#  <a class="product-image newamastylabels" href="https://www.senheng.com.my/haier-50-inch-4k-ultra-hd-smart-led-tv.html" title="Haier 50-inch 4K Ultra HD Smart LED TV LE50U6600U">
#  <img alt="Haier 50-inch 4K Ultra HD Smart LED TV LE50U6600U" class="" id="product-collection-image-25670" src="./data_manual_files/haier_le50u6600u_4k_smart_tv.png"/>
#  </a>
#  </div>
#  <div class="details-area">
#  <h2 class="product-name"><a href="https://www.senheng.com.my/haier-50-inch-4k-ultra-hd-smart-led-tv.html" title="Haier 50-inch 4K Ultra HD Smart LED TV LE50U6600U">Haier 50-inch 4K Ultra HD Smart LED TV LE50U6600U</a></h2>
#  <div class="ratings">
#  <div class="rating-box">
#  <div class="rating" style="width:0"></div>
#  </div>
#  </div>
#  <div class="short-desc">
#  <p>Smart Share function which connects with smartphone and pad<br/>Android Operating System and Wi-Fi connectivity<br/>Smart Cursor Remote Mouse Pointer<br/>Ultra High-Definition in 4K Crystal Clear Image</p> </div>
#  <div class="action-area">
#  <div class="price" id="amlabel-product-price-25670" style="display:none"></div>
#  <div class="price-box">
#  <p class="old-price">
#  <span class="price-label">Regular Price:</span>
#  <span class="price" id="old-price-25670">
#                      RM 2,829.00                </span>
#  </p>
#  <p class="special-price">
#  <span class="price-label">Special Price</span>
#  <span class="price" id="product-price-25670">
#                      RM 1,885.00                </span>
#  </p>
#  </div>
#  <div class="regular-price" style="text-align: left;">
#  <div class="myspe_price">
#  <span class="price">RM 1,885.00</span> </div>
#  <div class="myreg_price">
#  <span class="price-title">RRP: </span>
#  <span class="price">RM 2,829.00</span> </div>
#  </div>
#  <div class="myclear"><br/>
#  <div class="actions">
#  <div class="loader-container">
#  <div class="loader">
#  <i class="ajax-loader medium animate-spin"></i>
#  </div>
#  </div>
#  <a class="addtocart" href="javascript:void(0)" onclick="setLocationAjax(this,'https://www.senheng.com.my/checkout/cart/add/uenc/aHR0cHM6Ly93d3cuc2VuaGVuZy5jb20ubXkvYWxsLXByb2R1Y3RzL3R2cy1hdWRpb3MvdHYuaHRtbD9hamF4Y2F0YWxvZz10cnVlJm1vZGU9bGlzdA,,/product/25670/form_key/c8r9odHLggDMCmop/','25670')" title="Add to Cart"><i class="icon-cart"></i><span> Add to Cart</span></a>
#  <a class="addtowishlist" href="https://www.senheng.com.my/wishlist/index/add/product/25670/form_key/c8r9odHLggDMCmop/" title="Add to Wishlist"><i class="icon-wishlist"></i></a>
#  <div class="clearer"></div>
#  </div>
#  </div>
#  </div>
#  <div class="clearer"></div>
#  </div></div></li>,
#  <li class="item odd" data-val='["HSE-49A5700PW","Hisense 49-Inch HD LED Smart TV Model 49A5700PW"]' onclick="sendGa('HSE-49A5700PW','Hisense 49-Inch HD LED Smart TV Model 49A5700PW')"><div class="item-area">
#  <div class="product-image-area">
#  <a class="product-image newamastylabels" href="https://www.senheng.com.my/hisense-49-inch-hd-led-smart-tv.html" title="Hisense 49-Inch HD LED Smart TV Model 49A5700PW">
#  <img alt="Hisense 49-Inch HD LED Smart TV Model 49A5700PW" class="" id="product-collection-image-25674" src="./data_manual_files/49a5700pw_6xx.jpg"/>
#  </a>
#  </div>
#  <div class="details-area">
#  <h2 class="product-name"><a href="https://www.senheng.com.my/hisense-49-inch-hd-led-smart-tv.html" title="Hisense 49-Inch HD LED Smart TV Model 49A5700PW">Hisense 49-Inch HD LED Smart TV Model 49A5700PW</a></h2>
#  <div class="ratings">
#  <div class="rating-box">
#  <div class="rating" style="width:0"></div>
#  </div>
#  </div>
#  <div class="short-desc">
#  <p
form_key/c8r9odHLggDMCmop/" title="Add to Wishlist"><i class="icon-wishlist"></i></a>
#  <div class="clearer"></div>
#  </div>
#  </div>
#  </div>
#  <div class="clearer"></div>
#  </div></div></li>,
#  <li class="item" data-val='["TSB-55U7750VM","Toshiba 55-inch UHD 4K with Android TV TSB-55U7750VM"]' onclick="sendGa('TSB-55U7750VM','Toshiba 55-inch UHD 4K with Android TV TSB-55U7750VM')"><div class="item-area">
#  <div class="product-image-area">
#  <a class="product-image newamastylabels" href="https://www.senheng.com.my/toshiba-55-inch-uhd-4k-with-android-tv-tsb-55u7750vm.html" title="Toshiba 55-inch UHD 4K with Android TV TSB-55U7750VM">
#  <img alt="Toshiba 55-inch UHD 4K with Android TV TSB-55U7750VM" class="" id="product-collection-image-23776" src="./data_manual_files/u7750vm.jpg"/>
#  </a>
#  </div>
#  <div class="details-area">
#  <h2 class="product-name"><a href="https://www.senheng.com.my/toshiba-55-inch-uhd-4k-with-android-tv-tsb-55u7750vm.html" title="Toshiba 55-inch UHD 4K with Android TV TSB-55U7750VM">Toshiba 55-inch UHD 4K with Android TV TSB-55U7750VM</a></h2>
#  <div class="ratings">
#  <div class="rating-box">
#  <div class="rating" style="width:0"></div>
#  </div>
#  </div>
#  <div class="short-desc">
#  <p>55-inch UHD 4K with Android TV<br/>Chromecast Built-in<br/>CEVO 4K Engine<br/>Dolby Digital Plus<br/>DTS TruSurround<br/>AMR+ 800 Active Motion &amp; Resolution<br/>Picture Optimizer: 5 modes (User / Cinema / Sports / Vivid / Hi-Bright)<br/>Expandable memory with USB/HDD 3.0<br/>Supports connection with Bluetooth devices<br/>16GB Internal Memory<br/>HDMI x 3<br/>USB x 2</p> </div>
#  <div class="action-area">
#  <div class="price" id="amlabel-product-price-23776" style="display:none"></div>
#  <div class="price-box">
#  <p class="old-price">
#  <span class="price-label">Regular Price:</span>
#  <span class="price" id="old-price-23776">
#                      RM 4,092.00                </span>
#  </p>
#  <p class="special-price">
#  <span class="price-label">Special Price</span>
#  <span class="price" id="product-price-23776">
#                      RM 3,206.00                </span>
#  </p>
#  </div>
#  <div class="regular-price" style="text-align: left;">
#  <div class="myspe_price">
#  <span class="price">RM 3,206.00</span> </div>
#  <div class="myreg_price">
#  <span class="price-title">RRP: </span>
#  <span class="price">RM 4,092.00</span> </div>
#  </div>
#  <div class="myclear"><br/>
#  <div class="actions">
#  <div class="loader-container">
#  <div class="loader">
#  <i class="ajax-loader medium animate-spin"></i>
#  </div>
#  </div>
#  <a class="addtocart" href="javascript:void(0)" onclick="setLocationAjax(this,'https://www.senheng.com.my/checkout/cart/add/uenc/aHR0cHM6Ly93d3cuc2VuaGVuZy5jb20ubXkvYWxsLXByb2R1Y3RzL3R2cy1hdWRpb3MvdHYuaHRtbD9pbmZpbml0ZT10cnVlJm1vZGU9bGlzdCZwPTEw/product/23776/form_key/c8r9odHLggDMCmop/','23776')" title="Add to Cart"><i class="icon-cart"></i><span> Add to Cart</span></a>
#  <a class="addtowishlist" href="https://www.senheng.com.my/wishlist/index/add/product/23776/form_key/c8r9odHLggDMCmop/" title="Add to Wishlist"><i class="icon-wishlist"></i></a>
#  <div class="clearer"></div>
#  </div>
#  </div>
#  </div>
#  <div class="clearer"></div>
#  </div></div></li>]

# %% [markdown]
# ### Feature extraction

# %% [markdown]
# Now, we parse each HTML li element and extract the key information of each product (TV):
# - product id
# - name of the product
# - old price
# - current price
# - additional description
#
# In addition to the information above, we will also parse the name of the product and determine the following attributes:
# - brand of the product
# - inch (of the TV)
# - is it a 4K TV?
# - is it an UHD TV?
# - is it a LED?
# - is it an OLED TV?
# - is it an ULED TV?
# - is it a QLED TV?

# %%
dict_ls = []

for i, li in enumerate(li_elems):
    product_info = {}
    
    # Raw features
    product_info['id'] = None
    product_info['name'] = None
    product_info["old_price"] = None
    product_info["current_price"] = None
    product_info["description"] = None
    
    # Derived features
    product_info['brand'] = None
    product_info['inch'] = None
    product_info['X4K'] = 0
    product_info['UHD'] = 0
    product_info['LED'] = 0
    product_info['OLED'] = 0
    product_info['ULED'] = 0
    product_info['QLED'] = 0
    
    ###########################################################################
    #  Get Raw Features                                                       #
    ###########################################################################
    product_info['id'] = li.attrs['data-val'].split(",")[0][2:-1]
    product_info['name'] = li.attrs['data-val'].split(",")[1][1:-2]

    price_ls = li.find_all('span', class_='price')[0:2]
    for price_elem in price_ls:
        if len(price_elem.attrs) > 1 and ('old' in price_elem.attrs['id']):
            product_info['old_price'] = price_elem.get_text().strip()[2:]
            product_info['old_price'] = product_info['old_price'].strip().replace('RM', '').replace(',','')
            product_info['old_price'] = float(product_info['old_price'])
            
        else:
            product_info['current_price'] = price_elem.get_text().strip()[2:]
            product_info['current_price'] = product_info['current_price'].strip().replace('RM', '').replace(',','')
            product_info['current_price'] = float(product_info["current_price"])
    
    if li.find('div', class_='short-desc').find('p'):
        product_info['description'] = li.find('div', class_='short-desc').find('p').get_text()
    
    ###########################################################################
    #  Get Derived Features                                                   #
    ###########################################################################
    product_info['brand'] = product_info['id'].split('-')[0]
    
    # get inch
    if re.search('(\d+)\s?[-]?(inch)', product_info['name'], re.IGNORECASE):
        product_info['inch'] = re.search('(\d+)\s?[-]?(inch)', product_info['name'], re.IGNORECASE).group()
        product_info['inch'] = float(re.search('(\d+)', product_info['name']).group())
        
    elif re.search('(\d+)\s?["]', product_info['name']):
        product_info['inch'] = float(re.search('(\d+)\s?["]', product_info['name']).group().replace('"', '').strip())
    
    # get 4K, UHD, OLED, QLED, LED or ULED
    if re.search('\s(4K)\s', product_info['name'], re.IGNORECASE):
        product_info["X4K"] = 1
    if re.search('\s(ultra\s?|u)hd\s', product_info['name'], re.IGNORECASE):
        product_info["UHD"] = 1
    if re.search('\s(led)\s', product_info['name'], re.IGNORECASE):
        product_info["LED"] = 1
    if re.search('\s(oled)\s', product_info['name'], re.IGNORECASE):
        product_info["OLED"] = 1
    if re.search('\s(uled)\s', product_info['name'], re.IGNORECASE):
        product_info["ULED"] = 1
    if re.search('\s(qled)\s', product_info['name'], re.IGNORECASE):
        product_info["QLED"] = 1

    dict_ls.append(product_info)

# %% [markdown]
# Now we convert the list of dictionaries to a Pandas DataFrame.

# %%
df = pd.DataFrame(dict_ls)
df
# Out:
#     LED  OLED  QLED  UHD  ULED  X4K brand  current_price  \
# 0     1     0     0    0     0    0   HAI          749.0
# 1     1     0     0    1     0    1   HAI         1885.0
# 2     1     0     0    0     0    0   HSE         1599.0
# 3     1     0     0    0     0    0   HSE         1499.0
# 4     0     0     0    1     0    1   HSE         2399.0
# 5     0     0     0    1     0    0   HSE         2599.0
# 6     0     0     0    1     0    0   HSE         3899.0
# 7     0     0     0    1     0    0    LG         1799.0
# 8     0     0     0    1     0    0    LG         1999.0
# 6   65-Inch Ultra HD 3840×2160 HDR Technology Remo...    HSE-65A6501UW  65.0
# 7   High-Resolution for a razor sharp imageConsist...      LG-43UK6300  43.0
# 8    49-inchMulti-channelHigh-Resolution4K Active HDR      LG-49UK6320  49.0
# 9   Rich, accurate color and deeper blackSpectacul...      LG-49SK8000  49.0
# 10  4K Active HDRHDR EffectActive HDRTrue Colour A...      LG-50UK6500  50.0
# 11  Click HERE for redemption of free gift and fol...         LG-55B8P  55.0
# 12  Click HERE for redemption of free gift and fol...      LG-55UK6320  55.0
# 13  55-inchNano CellTM DisplayDTS VirtualUltra Lum...      LG-55UK7500  55.0
# 14  Click HERE for redemption of free gift and fol...          LG-65C8  65.0
# 15  Rich, accurate color and deeper blackSpectacul...      LG-65SK8500  65.0
# 16  Click HERE for redemption of free gift and fol...      LG-65UK6320  65.0
# 17  65-inchNano CellTM DisplayDTS VirtualUltra Lum...      LG-65UK7500  65.0
# 18   70-inchMulti-channelUltra Luminance4K Active HDR      LG-70UK6540  70.0
# 19  Rich, accurate color and deeper blackSpectacul...      LG-75SK8000  75.0
# 20  75-Inch/190cm Screen Size Web OS Smart TV4K HD...      LG-75UK6500  75.0
# 21  86-Inch/218cm Screen Size Web OS Smart TV4K HD...      LG-86UK6500  86.0
# 22  Glass TV DesignLG ThinQ® AI | Google Assistant...          LG-65E8  65.0
# 23  Curved Gaming, 1800R144 Hz Refresh Rate1ms Fas...       MSI-MAG24C  23.0
# 24  Curved Gaming, 1800R144 Hz Refresh Rate1ms Fas...       MSI-MAG27C  27.0
# 25                                                       PSN-TH32F400K  32.0
# 26  Hexa Chroma DriveHexa Boost IPS LEDAdaptive Ba...    PSN-TH40F400K  40.0
# 27  Natural 6-Colour ReproductioonHexa Chroma Driv...    PSN-TH43E410K  43.0
# 28  Hexa Chroma Drive ProIPS Super Bright Panel Pl...   PSN-TH49FX700K  49.0
# 29                                               None    PSN-TH49E410K  49.0
# ..                                                ...              ...   ...
# 69           4K UHD Easy Smart TVDolby Audio Surround  SHP-LC45UA6500X  45.0
# 70  4K Ultra HDAndroid TVHigh Luminance Technology...  SHP-LC50UA6800X  50.0
# 71  4K resolution Ultra High-DefinitionX4 Master E...    SHP-4TC50AH1X  50.0
# 72  50 inch Full HD Basic TVUSB Media Player - Exp...    SHP-2TC50AD1X  50.0
# 73  50 inch Full HD Easy Smart TVX2 Master Engine ...    SHP-2TC50AE1X  50.0
# 74  60 inch 4K UHD android TVX4 Master Engine Pro ...  SHP-LC60UA6800X  60.0
# 75  4K Ultra HD - AQUOS 4K TVs Latest HDR Standard...  SHP-LC60UA6500X  60.0
# 76  70-Inch 4K Ultra HD Android TV4K Ultra HD - AQ...    SHP-4TC70AL1X  70.0
# 77  80 cm (32")WXGA Resolution (1366 x 768)Dolby™ ...   SNY-KDL32R300E  32.0
# 78                                               None   SNY-KDL40W650D  40.0
# 79  102 cm (40")Full HD (1920 x 1080)Live Colour™ ...   SNY-KDL40R350E  40.0
# 80  High Dynamic RangeX-Reality™ PROClearAudio+Mot...   SNY-KDL43W660F  43.0
